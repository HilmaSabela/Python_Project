# %% [markdown]
# # Filtering and Ordering

# %%
import pandas as pd

# %%
df = pd.read_csv(r"H:\Phyton Tutorial\Web Scrapping\Web Scrapping Project 1\Companies_Project1.csv")
df
# Out:
#     Rank                                 Name  \
# 0      1                              Walmart
# 1      2                               Amazon
# 2      3                          Exxon Mobil
# 3      4                                Apple
# 4      5                   UnitedHealth Group
# 5      6                           CVS Health
# 6      7                   Berkshire Hathaway
# 7      8                             Alphabet
# 8      9                 McKesson Corporation
# 9     10                  Chevron Corporation
# 10    11                    AmerisourceBergen
# 11    12                               Costco
# 12    13                            Microsoft
# 13    14                      Cardinal Health
# 14    15                                Cigna
# 15    16                   Marathon Petroleum
# 16    17                          Phillips 66
# 17    18                        Valero Energy
# 18    19                   Ford Motor Company
# ...

# %%
pd.set_option('display.max.rows', 101)

# %%
df[df['Rank'] <= 10]
# Out:
#    Rank                  Name                    Industry  \
# 0     1               Walmart                      Retail
# 1     2                Amazon  Retail and cloud computing
# 2     3           Exxon Mobil          Petroleum industry
# 3     4                 Apple        Electronics industry
# 4     5    UnitedHealth Group                  Healthcare
# 5     6            CVS Health                  Healthcare
# 6     7    Berkshire Hathaway                Conglomerate
# 7     8              Alphabet                  Technology
# 8     9  McKesson Corporation                      Health
# 9    10   Chevron Corporation          Petroleum industry
#
#   Revenue (USD millions) Revenue growth  Employees               Headquarters
# 0                611,289           6.7%  2,100,000      Bentonville, Arkansas
# 1                513,983           9.4%  1,540,000        Seattle, Washington
# 2                413,680          44.8%     62,000              Spring, Texas
# ...

# %%
specific_industries = ['Healthcare','Technology']

df[df['Industry'].isin(specific_industries)]
# Out:
#     Rank                Name    Industry Revenue (USD millions)  \
# 4      5  UnitedHealth Group  Healthcare                324,162
# 5      6          CVS Health  Healthcare                322,467
# 7      8            Alphabet  Technology                282,836
# 12    13           Microsoft  Technology                198,270
# 13    14     Cardinal Health  Healthcare                181,364
# 21    22     Elevance Health  Healthcare                156,595
# 24    25             Centene  Healthcare                144,547
# 30    31      Meta Platforms  Technology                116,609
# 33    34   Dell Technologies  Technology                102,301
# 63    64               Intel  Technology                 63,054
# 64    65                  HP  Technology                 62,983
# 66    67                 IBM  Technology                 60,530
# 67    68      HCA Healthcare  Healthcare                 60,233
# 99   100            Qualcomm  Technology                 44,200
#
# ...

# %%
df[df['Industry'].str.contains('Technology')]
# Out:
#     Rank               Name    Industry Revenue (USD millions) Revenue growth  \
# 7      8           Alphabet  Technology                282,836           9.8%
# 12    13          Microsoft  Technology                198,270          18.0%
# 30    31     Meta Platforms  Technology                116,609           1.1%
# 33    34  Dell Technologies  Technology                102,301           4.4%
# 63    64              Intel  Technology                 63,054          20.1%
# 64    65                 HP  Technology                 62,983           0.8%
# 66    67                IBM  Technology                 60,530          16.3%
# 99   100           Qualcomm  Technology                 44,200          31.7%
#
#    Employees               Headquarters
# 7    156,000  Mountain View, California
# 12   221,000        Redmond, Washington
# 30    86,482     Menlo Park, California
# 33   133,000          Round Rock, Texas
# 63   131,900    Santa Clara, California
# ...

# %%
df2 = df.set_index('Industry')
df2
# Out:
#                                   Rank                                 Name  \
# Industry
# Retail                               1                              Walmart
# Retail and cloud computing           2                               Amazon
# Petroleum industry                   3                          Exxon Mobil
# Electronics industry                 4                                Apple
# Healthcare                           5                   UnitedHealth Group
# Healthcare                           6                           CVS Health
# Conglomerate                         7                   Berkshire Hathaway
# Technology                           8                             Alphabet
# Health                               9                 McKesson Corporation
# Petroleum industry                  10                  Chevron Corporation
# Pharmaceutical industry             11                    AmerisourceBergen
# ...

# %%
df2.filter(items = ['Rank', 'Headquarters'])
# Out:
#                                   Rank  \
# Industry
# Retail                               1
# Retail and cloud computing           2
# Petroleum industry                   3
# Electronics industry                 4
# Healthcare                           5
# Healthcare                           6
# Conglomerate                         7
# Technology                           8
# Health                               9
# Petroleum industry                  10
# Pharmaceutical industry             11
# Retail                              12
# Technology                          13
# Healthcare                          14
# Health Insurance                    15
# Petroleum industry                  16
# Petroleum industry                  17
# Petroleum industry                  18
# Automotive industry                 19
# Retail                              20
# Automotive                          21
# Healthcare                          22
# Financial services                  23
# ...

# %%
df2.filter(like = 'Health', axis = 0)
#items buat index
#like buat 1 value
#axis 1, nggak muncul, axis 0 muncul
# Out:
#                   Rank                  Name Revenue (USD millions)  \
# Industry
# Healthcare           5    UnitedHealth Group                324,162
# Healthcare           6            CVS Health                322,467
# Health               9  McKesson Corporation                276,711
# Healthcare          14       Cardinal Health                181,364
# Health Insurance    15                 Cigna                180,516
# Healthcare          22       Elevance Health                156,595
# Healthcare          25               Centene                144,547
# Health Insurance    42                Humana                 92,870
# Healthcare          68        HCA Healthcare                 60,233
#
#                  Revenue growth Employees              Headquarters
# Industry
# Healthcare                12.7%   400,000     Minnetonka, Minnesota
# Healthcare                10.4%   259,500  Woonsocket, Rhode Island
# ...

# %%
df2.iloc[22]
# Out:
# Rank                                           23
# Name                               JPMorgan Chase
# Revenue (USD millions)                    154,792
# Revenue growth                              21.7%
# Employees                                 293,723
# Headquarters              New York City, New York
# Name: Financial services, dtype: object

# %% [markdown]
# # Order by

# %%
df[df['Rank'] <= 10 ].sort_values(by = 'Revenue growth', ascending = True)
# Out:
#    Rank                  Name                    Industry  \
# 5     6            CVS Health                  Healthcare
# 4     5    UnitedHealth Group                  Healthcare
# 8     9  McKesson Corporation                      Health
# 2     3           Exxon Mobil          Petroleum industry
# 9    10   Chevron Corporation          Petroleum industry
# 0     1               Walmart                      Retail
# 3     4                 Apple        Electronics industry
# 1     2                Amazon  Retail and cloud computing
# 6     7    Berkshire Hathaway                Conglomerate
# 7     8              Alphabet                  Technology
#
#   Revenue (USD millions) Revenue growth  Employees               Headquarters
# 5                322,467          10.4%    259,500   Woonsocket, Rhode Island
# 4                324,162          12.7%    400,000      Minnetonka, Minnesota
# 8                276,711           4.8%     48,500              Irving, Texas
# ...
